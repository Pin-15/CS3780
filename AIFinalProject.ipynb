# %% [markdown]
# <a href="https://colab.research.google.com/github/Pin-15/CS3780/blob/main/AIFinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url="https://raw.githubusercontent.com/shavi2006/d1/main/RetentionSep1.csv"
df=pd.read_csv(url)
df.head()
# Out:
#    Yr2 Gender ResdCode Major  GPA1stSem Admit Type Summer PAL  HS GPA  \
# 0  NaN      F        R   NSG       0.00         FR        NaN    2.47
# 1    Y      M        R   MGT       3.64         FP        NaN    3.75
# 2  NaN      M        R   MGT       4.00         FR        NaN    2.21
# 3    Y      F        R    CJ       3.18         FR        NaN    2.90
# 4    Y      M        R  CYED       1.92         FP        NaN    2.81
#
#   PR State       IPEDS Race/Ethnicity  ... AttHrs Yr1 Earn Hrs < 30  \
# 0       MA  Black or African American  ...       17.0           1.0
# 1       MA                      White  ...       29.0           1.0
# 2       CT                      White  ...       12.0           1.0
# 3       TX       Hispanic of any race  ...       33.0           NaN
# 4       MA                      White  ...       30.0           NaN
#
#   Majr at Adm  FA  RegTermCred for Yr1 Fall  RegTermCred for Yr1 Spring  \
# ...

# %%
import numpy as np
df["Yr2"]=np.where(df["Yr2"]=="X",0,df["Yr2"])
df["Yr2"]=np.where(df["Yr2"]=="Y",0,df["Yr2"])
df["Yr2"].fillna(1,inplace=True)
df["Gender"].fillna("N/A",inplace=True)
df.isnull().sum()
df["Gender"].value_counts()
df["ResdCode"].fillna("R",inplace=True)
df["Major"].value_counts()
df["Major"].fillna("N/A",inplace=True)
df["GPA1stSem"].value_counts()
df['GPA1stSem'].fillna(df['GPA1stSem'].mean(), inplace=True)
df["Admit Type"].value_counts()
df["Admit Type"].fillna("FR",inplace=True)
df["Summer PAL"].fillna("N",inplace=True)
df["Summer PAL"].value_counts()
df['HS GPA'].fillna(df['HS GPA'].median(), inplace=True)
df['First Gener'].fillna('N', inplace=True)
df['EnterTransfHrs'].fillna(df['EnterTransfHrs'].mean(), inplace=True)
df['AttHrs Yr1'].fillna(df['AttHrs Yr1'].mean(), inplace=True)
df["Earn Hrs < 30"].fillna("N", inplace=True)
df["Majr at Adm "].value_counts()
df['Majr at Adm '].fillna('NSG', inplace=True)
df['FA'].fillna('P', inplace=True)
df["Spring Census Return"].fillna("1.0",inplace=True)
df["GPA 1st Term Group"].fillna("3.50 to 4.00",inplace=True)
df["HS GPA Group"].fillna("3.00 to 3.24",inplace=True)

df['PR State'] = df['PR State'].fillna('MA')

most_repeated = df['IPEDS Race/Ethnicity'].value_counts().idxmax()
print(most_repeated)

df['IPEDS Race/Ethnicity'] = df['IPEDS Race/Ethnicity'].fillna('Race and Ethnicity Unknown')

most_repeated = df['ResHall'].value_counts().idxmax()
print(most_repeated)

df['ResHall'] = df['ResHall'].fillna('COMMUTER')

most_repeated = df['ResdCode'].value_counts().idxmax()
print(most_repeated)

df['SO'] = df['SO'].fillna("N")
df.isnull().sum()
import seaborn as sns
sns.histplot(df["RegTermCred for Yr1 Fall"])
dm=df["RegTermCred for Yr1 Fall"].mean()
df["RegTermCred for Yr1 Fall"].fillna(dm,inplace=True)
sns.histplot(df["RegTermCred for Yr1 Spring"])
le=df["RegTermCred for Yr1 Spring"].mean()
df["RegTermCred for Yr1 Spring"].fillna(le,inplace=True)
df["Sports sum"].fillna("0.0",inplace=True)

df["AcdStand1stSem"].fillna("00",inplace=True)

df.isnull().sum()
df["HS GPA Group"].fillna("3.00 to 3.24",inplace=True)
df["GPA 1st Term Group"].value_counts()
df.dropna(subset=["GPA 1st Term Group"], inplace=True)

df["FA"].fillna("N/A", inplace=True)
# Out:
# <ipython-input-3-8a7add0bec46>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Yr2"].fillna(1,inplace=True)
# <ipython-input-3-8a7add0bec46>:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Yr2"].fillna(1,inplace=True)
# ...

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6418 entries, 0 to 6417
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Yr2                         6418 non-null   int64
#  1   Gender                      6418 non-null   object
#  2   ResdCode                    6418 non-null   object
#  3   Major                       6418 non-null   object
#  4   GPA1stSem                   6418 non-null   float64
#  5   Admit Type                  6418 non-null   object
#  6   Summer PAL                  6418 non-null   object
#  7   HS GPA                      6418 non-null   float64
#  8   PR State                    6418 non-null   object
#  9   IPEDS Race/Ethnicity        6418 non-null   object
#  10  ResHall                     6418 non-null   object
#  11  AcdStand1stSem              6418 non-null   object
#  12  SO                          6418 non-null   object
# ...

# %%
df.dtypes
# Out:
# Yr2                             int64
# Gender                         object
# ResdCode                       object
# Major                          object
# GPA1stSem                     float64
# Admit Type                     object
# Summer PAL                     object
# HS GPA                        float64
# PR State                       object
# IPEDS Race/Ethnicity           object
# ResHall                        object
# AcdStand1stSem                 object
# SO                             object
# First Gener                    object
# EnterTransfHrs                float64
# AttHrs Yr1                    float64
# Earn Hrs < 30                  object
# Majr at Adm                    object
# FA                             object
# RegTermCred for Yr1 Fall      float64
# RegTermCred for Yr1 Spring    float64
# Sports sum                     object
# Spring Census Return           object
# HS GPA Group                   object
# GPA 1st Term Group             object
# ...

# %%
df["Yr2"]=df["Yr2"].astype("str")
df["Gender"]=df["Gender"].astype("str")
df["ResdCode"]=df["ResdCode"].astype("str")
df["Major"]=df["Major"].astype("str")
df["Admit Type"]=df["Admit Type"].astype("str")
df["Summer PAL"]=df["Summer PAL"].astype("str")
df["Majr at Adm "]=df["Majr at Adm "].astype("str")
df["FA"]=df["FA"].astype("str")
df["Spring Census Return"]=df["Spring Census Return"].astype("str")
df["GPA 1st Term Group"]=df["GPA 1st Term Group"].astype("str")
df["HS GPA Group"]=df["HS GPA Group"].astype("str")
df["Earn Hrs < 30"]=df["Earn Hrs < 30"].astype("str")
df["AttHrs Yr1"]=df["AttHrs Yr1"].astype("int")
df["EnterTransfHrs"]=df["EnterTransfHrs"].astype("int")
df["First Gener"]=df["First Gener"].astype("str")

# %%
df.dtypes
# Out:
# Yr2                            object
# Gender                         object
# ResdCode                       object
# Major                          object
# GPA1stSem                     float64
# Admit Type                     object
# Summer PAL                     object
# HS GPA                        float64
# PR State                       object
# IPEDS Race/Ethnicity           object
# ResHall                        object
# AcdStand1stSem                 object
# SO                             object
# First Gener                    object
# EnterTransfHrs                  int64
# AttHrs Yr1                      int64
# Earn Hrs < 30                  object
# Majr at Adm                    object
# FA                             object
# RegTermCred for Yr1 Fall      float64
# RegTermCred for Yr1 Spring    float64
# Sports sum                     object
# Spring Census Return           object
# HS GPA Group                   object
# GPA 1st Term Group             object
# ...

# %%
df.head()
# Out:
#   Yr2 Gender ResdCode Major  GPA1stSem Admit Type Summer PAL  HS GPA PR State  \
# 0   1      F        R   NSG       0.00         FR          N    2.47       MA
# 1   0      M        R   MGT       3.64         FP          N    3.75       MA
# 2   1      M        R   MGT       4.00         FR          N    2.21       CT
# 3   0      F        R    CJ       3.18         FR          N    2.90       TX
# 4   0      M        R  CYED       1.92         FP          N    2.81       MA
#
#         IPEDS Race/Ethnicity  ... AttHrs Yr1 Earn Hrs < 30 Majr at Adm  FA  \
# 0  Black or African American  ...         17           1.0         /NSG  P
# 1                      White  ...         29           1.0          MGT  L
# 2                      White  ...         12           1.0          UND  P
# 3       Hispanic of any race  ...         33             N          ENG  P
# 4                      White  ...         30             N          MGT  L
#
# ...

# %%
df=pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    GPA1stSem  HS GPA  EnterTransfHrs  AttHrs Yr1  RegTermCred for Yr1 Fall  \
# 0       0.00    2.47               0          17                      17.0
# 1       3.64    3.75               0          29                      12.5
# 2       4.00    2.21               0          12                      12.0
# 3       3.18    2.90               4          33                      15.0
# 4       1.92    2.81               0          30                      12.5
#
#    RegTermCred for Yr1 Spring  Yr2_1  Gender_M  Gender_N/A  ResdCode_R  ...  \
# 0                         0.0   True     False       False        True  ...
# 1                        16.5  False      True       False        True  ...
# 2                         0.0   True      True       False        True  ...
# 3                        18.0  False     False       False        True  ...
# 4                        17.5  False      True       False        True  ...
#
# ...

# %%
df["GPA1stSem"] = (df["GPA1stSem"] - df["GPA1stSem"].min()) / (df["GPA1stSem"].max() - df["GPA1stSem"].min())
df["HS GPA"] = (df["HS GPA"] - df["HS GPA"].min()) / (df["HS GPA"].max() - df["HS GPA"].min())
df["EnterTransfHrs"] = (df["EnterTransfHrs"] - df["EnterTransfHrs"].min()) / (df["EnterTransfHrs"].max() - df["EnterTransfHrs"].min())
df["AttHrs Yr1"] = (df["AttHrs Yr1"] - df["AttHrs Yr1"].min()) / (df["AttHrs Yr1"].max() - df["AttHrs Yr1"].min())
df["RegTermCred for Yr1 Fall"] = (df["RegTermCred for Yr1 Fall"] - df["RegTermCred for Yr1 Fall"].min()) / (df["RegTermCred for Yr1 Fall"].max() - df["RegTermCred for Yr1 Fall"].min())
df["RegTermCred for Yr1 Spring"] = (df["RegTermCred for Yr1 Spring"] - df["RegTermCred for Yr1 Spring"].min()) / (df["RegTermCred for Yr1 Spring"].max() - df["RegTermCred for Yr1 Spring"].min())
df.describe()
# Out:
#          GPA1stSem       HS GPA  EnterTransfHrs   AttHrs Yr1  \
# count  6418.000000  6418.000000     6418.000000  6418.000000
# mean      0.694537     0.366546        0.020528     0.402647
# std       0.240934     0.181964        0.078169     0.134688
# min       0.000000     0.000000        0.000000     0.000000
# 25%       0.580000     0.210000        0.000000     0.395349
# 50%       0.750000     0.363333        0.000000     0.441860
# 75%       0.875000     0.500000        0.000000     0.488372
# max       1.000000     1.000000        1.000000     1.000000
#
#        RegTermCred for Yr1 Fall  RegTermCred for Yr1 Spring
# count               6418.000000                 6418.000000
# mean                   0.563321                    0.651499
# std                    0.163270                    0.242667
# min                    0.000000                    0.000000
# 25%                    0.411765                    0.642857
# ...

# %%
print(list(df.columns))
# Out:
# ['GPA1stSem', 'HS GPA', 'EnterTransfHrs', 'AttHrs Yr1', 'RegTermCred for Yr1 Fall', 'RegTermCred for Yr1 Spring', 'Yr2_1', 'Gender_M', 'Gender_N/A', 'ResdCode_R', 'Major_BA', 'Major_BCHM', 'Major_BIOL', 'Major_CHW', 'Major_CJ', 'Major_COED', 'Major_COM', 'Major_CS', 'Major_CYED', 'Major_DES', 'Major_ECED', 'Major_EEC', 'Major_ELEM', 'Major_ENG', 'Major_ENSC', 'Major_FSC', 'Major_GD', 'Major_HE', 'Major_IIM', 'Major_ILS', 'Major_IT', 'Major_MAPD', 'Major_MGT', 'Major_MRKT', 'Major_MTHE', 'Major_N/A', 'Major_NSG', 'Major_OSTE', 'Major_PH', 'Major_PHIL', 'Major_PHW', 'Major_PN', 'Major_PSY', 'Major_SA', 'Major_SD', 'Major_SOC', 'Major_SPED', 'Major_SRM', 'Major_UND', 'Major_VA', 'Admit Type_FP', 'Admit Type_FR', 'Summer PAL_Y', 'PR State_AK', 'PR State_AL', 'PR State_AR', 'PR State_AZ', 'PR State_BC', 'PR State_CA', 'PR State_CO', 'PR State_CT', 'PR State_DC', 'PR State_DE', 'PR State_FL', 'PR State_GA', 'PR State_HI', 'PR State_ID', 'PR State_IL', 'PR State_IN', 'PR State_KY', 'PR Stat
# ...

# %%
before=df.iloc[:,:6]
after=df.iloc[:,7:]
target=df.iloc[:,6]
df=pd.concat([before,after,target], axis=1,join="outer")
print(list(df.columns))
# Out:
# ['GPA1stSem', 'HS GPA', 'EnterTransfHrs', 'AttHrs Yr1', 'RegTermCred for Yr1 Fall', 'RegTermCred for Yr1 Spring', 'Gender_M', 'Gender_N/A', 'ResdCode_R', 'Major_BA', 'Major_BCHM', 'Major_BIOL', 'Major_CHW', 'Major_CJ', 'Major_COED', 'Major_COM', 'Major_CS', 'Major_CYED', 'Major_DES', 'Major_ECED', 'Major_EEC', 'Major_ELEM', 'Major_ENG', 'Major_ENSC', 'Major_FSC', 'Major_GD', 'Major_HE', 'Major_IIM', 'Major_ILS', 'Major_IT', 'Major_MAPD', 'Major_MGT', 'Major_MRKT', 'Major_MTHE', 'Major_N/A', 'Major_NSG', 'Major_OSTE', 'Major_PH', 'Major_PHIL', 'Major_PHW', 'Major_PN', 'Major_PSY', 'Major_SA', 'Major_SD', 'Major_SOC', 'Major_SPED', 'Major_SRM', 'Major_UND', 'Major_VA', 'Admit Type_FP', 'Admit Type_FR', 'Summer PAL_Y', 'PR State_AK', 'PR State_AL', 'PR State_AR', 'PR State_AZ', 'PR State_BC', 'PR State_CA', 'PR State_CO', 'PR State_CT', 'PR State_DC', 'PR State_DE', 'PR State_FL', 'PR State_GA', 'PR State_HI', 'PR State_ID', 'PR State_IL', 'PR State_IN', 'PR State_KY', 'PR State_LA', 'P
# ...

# %%
y = df.iloc[:, -1]
X = df.iloc[:, :-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
k = 5
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.77      0.88      0.82      1376
#         True       0.69      0.52      0.59       742
#
#     accuracy                           0.75      2118
#    macro avg       0.73      0.70      0.71      2118
# weighted avg       0.74      0.75      0.74      2118

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
lr = logreg.fit(X_train,y_train)
y_pred=lr.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.79      0.96      0.87      1376
#         True       0.87      0.53      0.66       742
#
#     accuracy                           0.81      2118
#    macro avg       0.83      0.74      0.76      2118
# weighted avg       0.82      0.81      0.79      2118

# %%
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(random_state=0)
dtc.fit(X_train,y_train)
preds6=dtc.predict(X_test)
print(classification_report(y_test,preds6))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.79      0.79      0.79      1376
#         True       0.60      0.60      0.60       742
#
#     accuracy                           0.72      2118
#    macro avg       0.69      0.69      0.69      2118
# weighted avg       0.72      0.72      0.72      2118

# %%
from sklearn.ensemble import RandomForestClassifier
RF= RandomForestClassifier()
RF.fit(X_train,y_train)
preds4=RF.predict(X_test)
print(classification_report(y_test,preds4))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.79      0.97      0.87      1376
#         True       0.89      0.52      0.66       742
#
#     accuracy                           0.81      2118
#    macro avg       0.84      0.75      0.76      2118
# weighted avg       0.83      0.81      0.80      2118

# %%
from sklearn.naive_bayes import GaussianNB
gnb= GaussianNB()
gnb.fit(X_train,y_train)
preds1=gnb.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, preds1))
print(classification_report(y_test,preds1))
# Out:
# 0.3720491029272899
#               precision    recall  f1-score   support
#
#        False       0.76      0.05      0.09      1376
#         True       0.36      0.97      0.52       742
#
#     accuracy                           0.37      2118
#    macro avg       0.56      0.51      0.31      2118
# weighted avg       0.62      0.37      0.24      2118

# %%
from sklearn import svm
sv = svm.SVC()
sv.fit(X_train,y_train)
preds5=sv.predict(X_test)
print(classification_report(y_test,preds5))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.79      0.97      0.87      1376
#         True       0.91      0.52      0.66       742
#
#     accuracy                           0.81      2118
#    macro avg       0.85      0.74      0.77      2118
# weighted avg       0.83      0.81      0.80      2118

# %%
from xgboost import XGBClassifier
model=XGBClassifier(objective="binary:logistic",n_estimators=100,max_depth=3,learning_rate=.1)

names_of_features= X_train.columns.tolist()
import re
feature_names_with_ = [re.sub(r"[\[\]<>]", "_", name) for name in names_of_features]
X_train.columns = feature_names_with_
X_test.columns = feature_names_with_

model.fit(X_train,y_train)
preds7=model.predict(X_test)
print(classification_report(y_test, preds7))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.79      0.97      0.87      1376
#         True       0.92      0.52      0.66       742
#
#     accuracy                           0.82      2118
#    macro avg       0.85      0.75      0.77      2118
# weighted avg       0.83      0.82      0.80      2118

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
lr = logreg.fit(X_train,y_train)

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.79      0.96      0.87      1376
#         True       0.87      0.53      0.66       742
#
#     accuracy                           0.81      2118
#    macro avg       0.83      0.74      0.76      2118
# weighted avg       0.82      0.81      0.79      2118

# %%
import numpy as np
param_grid = [ {'penalty':['l1','l2','elasticnet','none'], 'C' : np.logspace(-4,4,20), 'solver': ['lbfgs','newton-cg','liblinear','sag','saga'], 'max_iter' : [100,1000,2500,5000] } ]

# %%
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(lr,param_grid = param_grid, cv = 3, verbose=True,n_jobs=-1)
clf
# Out:
# GridSearchCV(cv=3, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid=[{'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                           'max_iter': [100, 1000, 2500, 5000],
#                           'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                           'solver': ['lbfgs', 'newton-cg', 'liblinear', 'sag',
#                                      'saga']}],
#              verbose=True)

# %%
best_clf = clf.fit(X_train,y_train)
best=best_clf.best_estimator_
# Out:
# Fitting 3 folds for each of 1600 candidates, totalling 4800 fits

# %%
 y_pred = best.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-3c1e3a513b50> in <cell line: 1>()
# ----> 1 y_pred = best.predict(X_test)
#
# NameError: name 'best' is not defined

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.79      0.96      0.87      1376
#         True       0.87      0.53      0.66       742
#
#     accuracy                           0.81      2118
#    macro avg       0.83      0.74      0.76      2118
# weighted avg       0.82      0.81      0.79      2118

# %%
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(random_state=0)
dtc.fit(X_train,y_train)
preds6=dtc.predict(X_test)
print(classification_report(y_test,preds6))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.79      0.79      0.79      1376
#         True       0.60      0.60      0.60       742
#
#     accuracy                           0.72      2118
#    macro avg       0.69      0.69      0.69      2118
# weighted avg       0.72      0.72      0.72      2118

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
# Define parameter grid for tuning
param_grid = {'max_depth': [2, 4, 6, 8], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]}
# Create a decision tree classifier
dtc = DecisionTreeClassifier(random_state=0)
# Use GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(estimator=dtc, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
# Access the best model
best_model = grid_search.best_estimator_
# Make predictions on the test set
y_pred = best_model.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.79      0.98      0.87      1376
#         True       0.92      0.52      0.66       742
#
#     accuracy                           0.82      2118
#    macro avg       0.86      0.75      0.77      2118
# weighted avg       0.84      0.82      0.80      2118

# %%
from sklearn.ensemble import RandomForestClassifier
RF= RandomForestClassifier()
RF.fit(X_train,y_train)
preds4=RF.predict(X_test)
print(classification_report(y_test,preds4))

# %%
param_dist = {
    'n_estimators': [50, 100, 200, 500],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt']
}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
rf= RandomForestClassifier()
grid_search = GridSearchCV(estimator=rf, param_grid=param_dist, cv=5, scoring='recall')

# %%
grid_search.fit(X_train, y_train)

# %%
best_model = grid_search.best_estimator_

# %%
y_pred = best_model.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
`

# %%
from sklearn import svm
sv = svm.SVC()
sv.fit(X_train,y_train)
preds5=sv.predict(X_test)
print(classification_report(y_test,preds5))

# %%
param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [0.1, 1, 10, 100], 'kernel': ['rbf', 'linear']}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import svm
sv = svm.SVC()
# Perform grid search with cross-validation
grid_search = GridSearchCV(sv, param_grid, cv=5)
grid_search.fit(X, y)

# Print the best hyperparameters
print("Best parameters:", grid_search.best_params_)

# Get the best model
best_svm = grid_search.best_estimator_

# %%
y_pred = best_svm.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %%
# !pip install xgboost
from xgboost import XGBClassifier
model=XGBClassifier(objective="binary:logistic",n_estimators=100,max_depth=3, learning_rate=.1)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print(classification_report(y_test,y_pred))

# %%
# !pip install xgboost
from xgboost import XGBClassifier
model=XGBClassifier(objective="binary:logistic",n_estimators=200,max_depth=3, learning_rate=.1)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print(classification_report(y_test,y_pred))

# %%
# !pip install xgboost
from xgboost import XGBClassifier
model=XGBClassifier(objective="binary:logistic",n_estimators=100,max_depth=3, learning_rate=.2)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print(classification_report(y_test,y_pred))

# %%
# !pip install xgboost
from xgboost import XGBClassifier
model=XGBClassifier(objective="binary:logistic",n_estimators=200,max_depth=3, learning_rate=.2)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print(classification_report(y_test,y_pred))

# %%
# !pip install shap
import shap
shap.initjs()

# %%
exp=shap.Explainer(RF)
shap_vals=exp.shap_values(X_test)
shap.summary_plot(shap_vals,X_test)

# %%
# !pip install shap
import shap
shap.initjs()

BestModel = model

exp=shap.Explainer(BestModel)
shap_vals=exp.shap_values(X_test)
shap.summary_plot(shap_vals,X_test)
